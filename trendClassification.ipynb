# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sklearn.metrics as metrics

# %%
data = pd.read_csv(r'drive/My Drive/Colab Notebooks/data_with_english_sentiment_aspect_copy_final.csv')

# %%
data.rename(columns = {'Aspect':'Trend'}, inplace = True)

# %%
data
# Out:
#                  Property Name  Review Rating  \
# 0       Corinthia Hotel London              5
# 1       Corinthia Hotel London              5
# 2       Corinthia Hotel London              5
# 3       Corinthia Hotel London              5
# 4       Corinthia Hotel London              5
# ...                        ...            ...
# 182769           The Rembrandt              4
# 182770           The Rembrandt              4
# 182771               The Savoy              5
# 182772               The Savoy              5
# 182773               The Savoy              5
#
#                                    Review Title  \
# 0             by far my best hotel in the world
# 1             by far my best hotel in the world
# 2             by far my best hotel in the world
# 3             by far my best hotel in the world
# 4             by far my best hotel in the world
# ...                                         ...
# 182769  excellent hotel in outstanding location
# 182770  excellent hotel in outstanding location
# 182771                           great a always
# 182772                           great a always
# 182773                           great a always
#
#                                               Review Text  Location  Food  \
# 0       i had a pleasure of staying in this hotel for ...         0     0
# 1                      this hotel wa perfect in every way         0     0
# 2       communication with the hotel before staying wa...         0     0
# 3                                 checking in wa a breeze         0     0
# 4       you go through the spectacular lobby with mode...         0     0
# ...                                                   ...       ...   ...
# 182769  an excellent breakfast is served in the hotel ...         0     1
# 182770              an excellent hotel for london tourist         1     0
# 182771  i have been staying in london hotel for year n...         0     0
# 182772  i watched the to programme on the setting up o...         0     1
# 182773  well what can i say you are made to feel welco...         0     0
#
#         Staff  Experience/Value  Service  Room             Trend  \
# 0           0                 1        0     0  Experience/Value
# 1           0                 1        0     0  Experience/Value
# 2           1                 0        0     0             Staff
# 3           0                 0        0     1              Room
# 4           0                 0        0     1              Room
# ...       ...               ...      ...   ...               ...
# 182769      0                 0        0     0              Food
# 182770      0                 0        0     0          Location
# 182771      0                 1        0     0  Experience/Value
# 182772      0                 0        0     0              Food
# 182773      1                 0        0     0             Staff
#
#         Sentiment Score  Sentiment Sentiments
# 0                 0.252          2        pos
# 1                 0.381          2        pos
# 2                 0.236          2        pos
# 3                 0.000          1        neu
# 4                 0.064          2        pos
# ...                 ...        ...        ...
# 182769            0.316          2        pos
# 182770            0.425          2        pos
# 182771            0.000          1        neu
# 182772            0.000          1        neu
# 182773            0.181          2        pos
#
# [182774 rows x 14 columns]

# %%
from sklearn import preprocessing, model_selection, naive_bayes
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import string
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense, Embedding, LSTM,Input,Reshape,Flatten
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
x_tokenized = [sentence.split() for sentence in data["Review Text"]]

# %%
tokens= []
for i in range(len(x_tokenized)):
    for word in x_tokenized[i]:
        tokens.append(word)
vocab = len(set(tokens))

tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_tokenized)
sequences = tokenizer.texts_to_sequences(x_tokenized)
xInput = pad_sequences(sequences,maxlen=30,padding='post')

# %%
encoder = preprocessing.LabelEncoder()
y = encoder.fit_transform( data["Trend"])
from tensorflow.keras.utils import to_categorical
y = to_categorical( y, 6, dtype='int')

# %%
y.shape
# Out:
# (182774, 6)

# %%
xInput.shape
# Out:
# (182774, 30)

# %%
vocab_size = len(tokenizer.word_index)+1

# %%
from keras.layers import Dropout
from keras.regularizers import l2

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length = 30))
model.add(LSTM(100, return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
#model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(6, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 30, 100)           2491400
#
#  lstm (LSTM)                 (None, 30, 100)           80400
#
#  dropout (Dropout)           (None, 30, 100)           0
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 100)               10100
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 6)                 306
#
# =================================================================
# Total params: 2,667,656
# Trainable params: 2,667,656
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
# Out:
# WARNING:tensorflow:From <ipython-input-18-cef63d6acc25>:2: experimental_run_functions_eagerly (from tensorflow.python.eager.def_function) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.run_functions_eagerly` instead of the experimental version.

# %%
opt=tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer=opt, metrics = ['accuracy'])

# %%
history1 = model.fit(xInput, y, batch_size=64, epochs=45, shuffle=True, validation_split=0.3) #validation_data=[valid_x, valid_y], epochs=60)
# history = model.fit(xtrain, train_y, batch_size=32, epochs=60)
# Out:
# Epoch 1/45
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 2000/2000 [==============================] - 94s 44ms/step - loss: 1.1135 - accuracy: 0.6423 - val_loss: 1.4281 - val_accuracy: 0.5534
# Epoch 2/45
# 2000/2000 [==============================] - 95s 47ms/step - loss: 0.8758 - accuracy: 0.7593 - val_loss: 1.4468 - val_accuracy: 0.5639
# Epoch 3/45
# 2000/2000 [==============================] - 94s 47ms/step - loss: 0.8197 - accuracy: 0.7828 - val_loss: 1.4638 - val_accuracy: 0.5592
# Epoch 4/45
# 2000/2000 [==============================] - 94s 47ms/step - loss: 0.7877 - accuracy: 0.7956 - val_loss: 1.4704 - val_accuracy: 0.5648
# Epoch 5/45
# 2000/2000 [==============================] - 88s 44ms/step - loss: 0.7618 - accuracy: 0.8052 - val_loss: 1.4886 - val_accuracy: 0.5625
# Epoch 6/45
# 2000/2000 [==============================] - 89s 44ms/step - loss: 0.7399 - accuracy: 0.8127 - val_loss: 1.4937 - val_accuracy: 0.5647
# Epoch 7/45
# 2000/2000 [==============================] - 88s 44ms/step - loss: 0.7201 - accuracy: 0.8197 - val_loss: 1.4574 - val_accuracy: 0.5648
# Epoch 8/45
# 2000/2000 [==============================] - 89s 44ms/step - loss: 0.7016 - accuracy: 0.8255 - val_loss: 1.5472 - val_accuracy: 0.5619
# Epoch 9/45
# 2000/2000 [==============================] - 94s 47ms/step - loss: 0.6802 - accuracy: 0.8321 - val_loss: 1.5995 - val_accuracy: 0.5610
# Epoch 10/45
# 2000/2000 [==============================] - 88s 44ms/step - loss: 0.6613 - accuracy: 0.8364 - val_loss: 1.6416 - val_accuracy: 0.5586
# Epoch 11/45
# 2000/2000 [==============================] - 94s 47ms/step - loss: 0.6444 - accuracy: 0.8410 - val_loss: 1.6830 - val_accuracy: 0.5596
# Epoch 12/45
# 2000/2000 [==============================] - 88s 44ms/step - loss: 0.6265 - accuracy: 0.8456 - val_loss: 1.7221 - val_accuracy: 0.5529
# Epoch 13/45
# 2000/2000 [==============================] - 94s 47ms/step - loss: 0.6112 - accuracy: 0.8485 - val_loss: 1.7150 - val_accuracy: 0.5559
# Epoch 14/45
45
# 2000/2000 [==============================] - 87s 43ms/step - loss: 0.4178 - accuracy: 0.8876 - val_loss: 2.6085 - val_accuracy: 0.5341
# Epoch 34/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.4107 - accuracy: 0.8886 - val_loss: 2.8691 - val_accuracy: 0.5329
# Epoch 35/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.4017 - accuracy: 0.8900 - val_loss: 2.8160 - val_accuracy: 0.5326
# Epoch 36/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.3949 - accuracy: 0.8912 - val_loss: 3.0829 - val_accuracy: 0.5339
# Epoch 37/45
# 2000/2000 [==============================] - 93s 47ms/step - loss: 0.3887 - accuracy: 0.8933 - val_loss: 3.0660 - val_accuracy: 0.5352
# Epoch 38/45
# 2000/2000 [==============================] - 87s 43ms/step - loss: 0.3818 - accuracy: 0.8945 - val_loss: 2.9744 - val_accuracy: 0.5297
# Epoch 39/45
# 2000/2000 [==============================] - 87s 43ms/step - loss: 0.3734 - accuracy: 0.8962 - val_loss: 3.1675 - val_accuracy: 0.5279
# Epoch 40/45
# 2000/2000 [==============================] - 93s 47ms/step - loss: 0.3690 - accuracy: 0.8969 - val_loss: 3.0300 - val_accuracy: 0.5287
# Epoch 41/45
# 2000/2000 [==============================] - 93s 47ms/step - loss: 0.3639 - accuracy: 0.8983 - val_loss: 3.2587 - val_accuracy: 0.5285
# Epoch 42/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.3560 - accuracy: 0.8993 - val_loss: 3.2177 - val_accuracy: 0.5306
# Epoch 43/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.3502 - accuracy: 0.9016 - val_loss: 3.0412 - val_accuracy: 0.5230
# Epoch 44/45
# 2000/2000 [==============================] - 93s 46ms/step - loss: 0.3451 - accuracy: 0.9022 - val_loss: 3.1285 - val_accuracy: 0.5257
# Epoch 45/45
# 2000/2000 [==============================] - 100s 50ms/step - loss: 0.3382 - accuracy: 0.9036 - val_loss: 3.2869 - val_accuracy: 0.5156

# %%
import matplotlib.pyplot as plt
loss_train = history1.history['loss']
epochs = range(45)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history1.history['accuracy']
epochs = range(45)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.title('Training accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save('/content/drive/MyDrive/SaveModel-Trend')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SaveModel-Trend/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SaveModel-Trend/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7ef03fcad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f7ef02b8fd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
loss_val = history.history['accuracy']
epochs = range(45)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model2 = Sequential()
model2.add(Embedding(vocab_size, 100, input_length = 30))
model2.add(LSTM(100, return_sequences = True))
model2.add(Dropout(0.3))
model2.add(LSTM(100))
model2.add(Dropout(0.3))
#model.add(Flatten())
model2.add(Dense(100, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(50, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(3, activation='softmax'))

# %%
opt=tf.keras.optimizers.Adam(learning_rate=0.01)
model2.compile(loss = 'categorical_crossentropy', optimizer=opt, metrics = ['accuracy'])

# %%
encoder = preprocessing.LabelEncoder()
y2 = encoder.fit_transform( data["Sentiment"])
from tensorflow.keras.utils import to_categorical
y2 = to_categorical( y2, 3, dtype='int')

# %%
history2 = model2.fit(xInput, y2, batch_size=32, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/60
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 4511/4570 [============================>.] - ETA: 4s - loss: 0.3466 - accuracy: 0.8850

# %%
model.save('/content/drive/MyDrive/SaveModel')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SaveModel/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SaveModel/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f0a8ddfbad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f0a8dd900d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model.predict(xtrain[0:1]) # EFLRSeSt
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# array([[9.7288734e-01, 2.9335939e-05, 5.6869169e-08, 1.6862061e-03,
#         9.3994765e-07, 2.5396103e-02]], dtype=float32)
